# %%
# импортируем numpy и pandas
import numpy as np
import pandas as pd

# импортируем datetime
import datetime
from datetime import datetime, date

kino = pd.read_csv("Data/new_year_film.csv", index_col='name')
kino.head()
# Out:
#                              country  time ranking   type  year       director
# name
# Невеста                       Россия    74    7,66  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер   Россия    90   6,038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка           Россия    90   6,828  фильм  2007  Билли Уайлдер
# Набережная Орфевр            Франция   106   7,597  фильм  1947  Билли Уайлдер
# Лузер                         Россия   104   6,065  фильм  2007  Билли Уайлдер

# %% [markdown]
# ### Переименование столбцов

# %% [markdown]
# Полезно, когда хотим убрать пробелы из названий столбцов.
#
# Программный код возращает копию датафрейма с переименованным столбцом.

# %%
kino_rename = kino.rename(columns={'time': 'time_film'})
kino_rename[:2]
# Out:
#                             country  time_film ranking   type  year  \
# name
# Невеста                      Россия         74    7,66  фильм  2006
# Кто приходит в зимний вечер  Россия         90   6,038  фильм  2006
#
#                                   director
# name
# Невеста                      Билли Уайлдер
# Кто приходит в зимний вечер  Билли Уайлдер

# %%
kino.rename(columns={'time': 'time_film'},                   
           inplace=True)  # переименовывает столбец на месте
kino.columns
# Out:
# Index(['country', 'time_film', 'ranking', 'type', 'year', 'director'], dtype='object')

# %% [markdown]
# ### Добавление новых столбцов с помощью оператора [] и метода .insert()

# %%
kino_copy = kino.copy()
kino_copy.ranking = kino_copy.ranking.str.replace(',','.')
kino_copy.ranking = kino_copy.ranking.astype(float)
kino_copy.ranking
# Out:
# name
# Невеста                                             7.660
# Кто приходит в зимний вечер                         6.038
# Моя мама Снегурочка                                 6.828
# Набережная Орфевр                                   7.597
# Лузер                                               6.065
#                                                     ...
# Карнавальная ночь                                   7.929
# Квартира                                            8.021
# Когда зажигаются елки                               7.940
# Кошмар перед Рождеством                             8.049
# Красавица и чудовище: Чудесное Рождество (видео)    6.814
# Name: ranking, Length: 150, dtype: float64

# %%
# добавляем столбец
kino_copy['rounded_ranking'] = kino_copy.ranking.round()
kino_copy[:2]
# Out:
#                             country  time  ranking   type  year  \
# name
# Невеста                      Россия    74    7.660  фильм  2006
# Кто приходит в зимний вечер  Россия    90    6.038  фильм  2006
#
#                                   director  rounded_ranking
# name
# Невеста                      Билли Уайлдер              8.0
# Кто приходит в зимний вечер  Билли Уайлдер              6.0

# %%
kino_copy = kino.copy()
kino_copy.ranking = kino_copy.ranking.str.replace(',','.')
kino_copy.ranking = kino_copy.ranking.astype(float)
# вставляем столбец rounded_ranking в качестве второго столбца датафрейма
kino_copy.insert(1, 'rounded_ranking', kino_copy.ranking.round())
kino_copy[:2]
# Out:
#                             country  rounded_ranking  time  ranking   type  \
# name
# Невеста                      Россия              8.0    74    7.660  фильм
# Кто приходит в зимний вечер  Россия              6.0    90    6.038  фильм
#
#                              year       director
# name
# Невеста                      2006  Билли Уайлдер
# Кто приходит в зимний вечер  2006  Билли Уайлдер

# %% [markdown]
# ### Добавление столбцов за счет расширения датафрейма

# %%
kino_copy = kino[:3].copy()

# %%
kino_copy.loc[:,'imdb'] = 0 # добавляем столбец с нулевыми значениями
kino_copy
# Out:
#                                                   country  time_film ranking  \
# name
# Невеста                                            Россия         74    7,66
# Кто приходит в зимний вечер                        Россия         90   6,038
# Моя мама Снегурочка                                Россия         90   6,828
# Набережная Орфевр                                 Франция        106   7,597
# Лузер                                              Россия        104   6,065
# ...                                                   ...        ...     ...
# Карнавальная ночь                                    СССР         78   7,929
# Квартира                                              США        125   8,021
# Когда зажигаются елки                                СССР         20    7,94
# Кошмар перед Рождеством                               США         76   8,049
# Красавица и чудовище: Чудесное Рождество (видео)      США         72   6,814
#
#                                                         type  year  \
# name
# Невеста                                                фильм  2006
# Кто приходит в зимний вечер                            фильм  2006
# Моя мама Снегурочка                                    фильм  2007
# Набережная Орфевр                                      фильм  1947
# Лузер                                                  фильм  2007
# ...                                                      ...   ...
# Карнавальная ночь                                      фильм  1956
# Квартира                                               фильм  1960
# Когда зажигаются елки                             мультфильм  1950
# Кошмар перед Рождеством                           мультфильм  1993
# Красавица и чудовище: Чудесное Рождество (видео)  мультфильм  1997
#
#                                                        director  imdb
# name
# Невеста                                           Билли Уайлдер     0
# Кто приходит в зимний вечер                       Билли Уайлдер     0
# Моя мама Снегурочка                               Билли Уайлдер     0
# Набережная Орфевр                                 Билли Уайлдер     0
# Лузер                                             Билли Уайлдер     0
# ...                                                         ...   ...
# Карнавальная ночь                                           NaN     0
# Квартира                                                    NaN     0
# Когда зажигаются елки                                       NaN     0
# Кошмар перед Рождеством                                     NaN     0
# Красавица и чудовище: Чудесное Рождество (видео)            NaN     0
#
# [150 rows x 7 columns]

# %%
kino_copy = kino[:3].copy()

# %%
# добавляем новый столбец со случайно сгенерированными значениями
kino_copy.loc[:,'imdb'] = pd.Series(np.random.randint(1, 10), index=kino_copy.index)
kino_copy
# Out:
#                             country  time_film ranking   type  year  \
# name
# Невеста                      Россия         74    7,66  фильм  2006
# Кто приходит в зимний вечер  Россия         90   6,038  фильм  2006
# Моя мама Снегурочка          Россия         90   6,828  фильм  2007
#
#                                   director  imdb
# name
# Невеста                      Билли Уайлдер     6
# Кто приходит в зимний вечер  Билли Уайлдер     6
# Моя мама Снегурочка          Билли Уайлдер     6

# %% [markdown]
# ### Удаление столбцов

# %% [markdown]
# Пример использования del для удаления столбца.

# %%
kino_copy = kino.copy()
del kino_copy['director']
kino_copy[:2]
# Out:
#                             country  time ranking   type  year
# name
# Невеста                      Россия    74    7,66  фильм  2006
# Кто приходит в зимний вечер  Россия    90   6,038  фильм  2006

# %%
# пример использования drop для удаления столбца из датафрейма
kino_copy = kino.copy()
# эта строка вернет новый датафрейм с удаленным столбцом 'director’
# копия датафрейма не изменится
afterdrop = kino_copy.drop(['director'], axis=1) 
afterdrop[:5]
# Out:
#                              country  time ranking   type  year
# name
# Невеста                       Россия    74    7,66  фильм  2006
# Кто приходит в зимний вечер   Россия    90   6,038  фильм  2006
# Моя мама Снегурочка           Россия    90   6,828  фильм  2007
# Набережная Орфевр            Франция   106   7,597  фильм  1947
# Лузер                         Россия   104   6,065  фильм  2007

# %% [markdown]
# ### Присоединение строк из других объектов DataFrame с помощью метода .append()

# %%
df1 = kino.iloc[0:3].copy() # копируем первые три строки датафрейма kino
df1
# Out:
#                             country  time ranking   type  year       director
# name
# Невеста                      Россия    74    7,66  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер  Россия    90   6,038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка          Россия    90   6,828  фильм  2007  Билли Уайлдер

# %%
df2 = kino.iloc[[10, 11, 2]] # копируем строки в позициях 10, 11 и 2
df2
# Out:
#                        country  time ranking   type  year       director
# name
# Магазинчик за углом        США    99   7,921  фильм  1940  Билли Уайлдер
# Мужчина в моей голове   Россия   113   7,143  фильм  2009  Билли Уайлдер
# Моя мама Снегурочка     Россия    90   6,828  фильм  2007  Билли Уайлдер

# %%
appended = df1.append(df2) # присоединяем к датафрейму df1 датафрейм df2
# в результате к строкам первого датафрейма будут присоединены строки второго датафрейма
appended
# Out:
#                             country  time ranking   type  year       director
# name
# Невеста                      Россия    74    7,66  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер  Россия    90   6,038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка          Россия    90   6,828  фильм  2007  Билли Уайлдер
# Магазинчик за углом             США    99   7,921  фильм  1940  Билли Уайлдер
# Мужчина в моей голове        Россия   113   7,143  фильм  2009  Билли Уайлдер
# Моя мама Снегурочка          Россия    90   6,828  фильм  2007  Билли Уайлдер

# %% [markdown]
# ### Конкатенация строк

# %%
# копируем первые три строки датафрейма kino
df1 = kino.iloc[0:3].copy()
# копируем строки в позициях 10, 11 и 2
df2 = kino.iloc[[10, 11, 2]]
# передаем их в виде списка
pd.concat([df1, df2])
# Out:
#                             country  time ranking   type  year       director
# name
# Невеста                      Россия    74    7,66  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер  Россия    90   6,038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка          Россия    90   6,828  фильм  2007  Билли Уайлдер
# Магазинчик за углом             США    99   7,921  фильм  1940  Билли Уайлдер
# Мужчина в моей голове        Россия   113   7,143  фильм  2009  Билли Уайлдер
# Моя мама Снегурочка          Россия    90   6,828  фильм  2007  Билли Уайлдер

# %% [markdown]
# ### Удаление строк с помощью метода .drop()

# %%
kino_copy = kino[:5]
kino_copy
# Out:
#                              country  time ranking   type  year       director
# name
# Невеста                       Россия    74    7,66  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер   Россия    90   6,038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка           Россия    90   6,828  фильм  2007  Билли Уайлдер
# Набережная Орфевр            Франция   106   7,597  фильм  1947  Билли Уайлдер
# Лузер                         Россия   104   6,065  фильм  2007  Билли Уайлдер

# %%
afterdrop = kino_copy.drop(['Моя мама Снегурочка', 'Набережная Орфевр'])
afterdrop[:5]
# Out:
#                             country  time ranking   type  year       director
# name
# Невеста                      Россия    74    7,66  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер  Россия    90   6,038  фильм  2006  Билли Уайлдер
# Лузер                        Россия   104   6,065  фильм  2007  Билли Уайлдер

# %% [markdown]
# ### Удаление строк с помощью логического отбора

# %%
kino.ranking = kino.ranking.str.replace(',','.')
kino.ranking = kino.ranking.astype(float)

# %%
# определяем строки, в которых ranking > 6
selection = kino.ranking > 6
# выводим информацию о количестве строк и количестве строк, которые будут удалены
(len(selection), selection.sum())
# Out:
# (150, 136)

# %%
# для отбора применим побитовое отрицание к выражению selection
not_selection = kino[~selection]
not_selection
# Out:
#                                       country  time  ranking        type  \
# name
# Ой, мороз, мороз!                       РСФСР    95    5.775       фильм
# Новогодний детектив                    Россия    90    5.981       фильм
# Откройте, Дед Мороз!                    РСФСР    98    5.318       фильм
# Приключения Снеговика Фрости              США    25    5.677  мультфильм
# Сверчок за очагом                      Россия   107    5.860       фильм
# Тушите свет                            Россия    75    5.856       фильм
# Убить карпа                            Россия   100    6.000       фильм
# 32 декабря                             Россия   104    5.992       фильм
# В город приехал Санта-Клаус!              США    48    5.254  мультфильм
# Год без Санты                             США    51    5.418  мультфильм
# Дед Мороз                      Великобритания    25    5.473  мультфильм
# Дед Мороз поневоле                     Россия    77    5.990       фильм
# Идеальное Рождество Артура                США    60    4.900  мультфильм
# Иисус против Санты                        США     5    5.952  мультфильм
#
#                                year            director
# name
# Ой, мороз, мороз!              2005  Джиллиан Армстронг
# Новогодний детектив            2010  Джиллиан Армстронг
# Откройте, Дед Мороз!           2007  Джиллиан Армстронг
# Приключения Снеговика Фрости   1969        Майк Митчелл
# Сверчок за очагом              2001        Майкл Саймон
# Тушите свет                    2008        Майкл Саймон
# Убить карпа                    2005        Майкл Саймон
# 32 декабря                     2004                 NaN
# В город приехал Санта-Клаус!   1970                 NaN
# Год без Санты                  1974                 NaN
# Дед Мороз                      1991                 NaN
# Дед Мороз поневоле             2007                 NaN
# Идеальное Рождество Артура     2000                 NaN
# Иисус против Санты             1995                 NaN

# %% [markdown]
# ### Удаление строк с помощью среза

# %%
# отбираем лишь первые три строки
only_first_three = kino[:3]
only_first_three
# Out:
#                             country  time  ranking   type  year       director
# name
# Невеста                      Россия    74    7.660  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер  Россия    90    6.038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка          Россия    90    6.828  фильм  2007  Билли Уайлдер

# %%
only_first_three = kino[:3].copy()
only_first_three
# Out:
#                             country  time  ranking   type  year       director
# name
# Невеста                      Россия    74    7.660  фильм  2006  Билли Уайлдер
# Кто приходит в зимний вечер  Россия    90    6.038  фильм  2006  Билли Уайлдер
# Моя мама Снегурочка          Россия    90    6.828  фильм  2007  Билли Уайлдер
