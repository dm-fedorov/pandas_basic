# %% [markdown]
# Решение задачи группировки предполагает разделение данных по некоторому признаку (атрибуту), после чего к каждому элементу этих разделенных данных мы можем применить агрегирующую операцию. Это такая операция, которая позволяет вычислить какой-либо показатель.
#
# Затем мы можем оценить, как отличаются эти показатели в зависимости от признака, по которому было осуществлено разделение. Такое разделение мы можем назвать группировкой данных.
#
# Возьмем по 5 футболистов трех различных национальностей, а затем посчитаем средний возраст внутри каждой из национальностей.

# %% [markdown]
# Этот пример немного далёк от реальности, с которой приходится иметь дело в ходе полноценного анализа данных, так как мы специально, для простоты восприятия, взяли по 5 футболистов из каждой национальности. На основе таких маленьких выборок сложно строить какие-то выводы. Но даже такой простой пример позволяет делать некоторые выводы и демонстрирует важность группировки данных. Мы видим, что средний возраст приблизительно одинаков между всеми тремя группами. Но посмотрите на разброс возраста между футболистами внутри каждой из групп по 5 футболистов.
#
# Можно заметить, что разброс возраста между футболистам в группе аргентинских и бразильских футболистов меньше, чем среди португальских футболистов. Это легко выразить численно, если применить вместо среднего другую агрегирующую функцию и посчитать среднеквадратичное отклонение:

# %% [markdown]
# Мы видим, что метрика среднеквадратического отклонения выше в группе португальских футболистов, хотя среднее точно совпадает со средним внутри бразильской группы. Вот почему так важно применять методы группировки в ходе анализа данных: это позволяет сделать вывод о группе данных на основе совокупных признаков, сравнивая показатели внутри группы с показателями другой группы.

# %%
import pandas as pd

football = pd.read_csv('../data/football.csv')
football.head()
# Out:
#    Unnamed: 0               Name  Age Nationality                 Club  \
# 0           0           L. Messi   31   Argentina         FC Barcelona
# 1           1  Cristiano Ronaldo   33    Portugal             Juventus
# 2           2          Neymar Jr   26      Brazil  Paris Saint-Germain
# 3           3             De Gea   27       Spain    Manchester United
# 4           4       K. De Bruyne   27     Belgium      Manchester City
#
#        Value    Wage Position  Crossing  Finishing  ...  Penalties  Composure  \
# 0  110500000  565000       RF        84         95  ...         75         96
# 1   77000000  405000       ST        84         94  ...         85         95
# 2  118500000  290000       LW        79         87  ...         81         94
# 3   72000000  260000       GK        17         13  ...         40         68
# 4  102000000  355000      RCM        93         82  ...         79         88
#
# ...
