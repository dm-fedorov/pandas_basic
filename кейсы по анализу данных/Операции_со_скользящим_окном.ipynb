# %% [markdown]
# <a href="https://colab.research.google.com/github/dm-fedorov/pandas_basic/blob/master/кейсы%20по%20анализу%20данных/Операции_со_скользящим_окном.ipynb"><img align="left" src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open in Colab" title="Open and Execute in Google Colaboratory" target="_blank"></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# Создаем случайное блуждание:

# %%
s = pd.Series(np.random.randn(1000)).cumsum()
s[:5]
# Out:
# 0   -0.390533
# 1   -0.049881
# 2   -0.918999
# 3   -3.065232
# 4   -4.784517
# dtype: float64

# %%
s[:100].plot();

# %% [markdown]
# Вычисляем скользящее окно шириной три дня:

# %%
r = s.rolling(window=3)
r
# Out:
# Rolling [window=3,center=False,axis=0]

# %% [markdown]
# Скользящее среднее по трем дням:

# %%
means = r.mean()
means[:7]
# Out:
# 0         NaN
# 1         NaN
# 2   -0.453138
# 3   -1.344704
# 4   -2.922916
# 5   -4.760603
# 6   -6.389492
# dtype: float64

# %% [markdown]
# Проверяем, является ли значение средним первых трех чисел:

# %%
s[0:3].mean()
# Out:
# -0.453137631031679

# %% [markdown]
# Среднее для меток с 1 по 3:

# %%
s[1:4].mean()
# Out:
# -1.3447041406057105

# %% [markdown]
# Строим график на основе 3-дневного скользящего среднего:

# %%
means[:100].plot();
