# %%
import pandas as pd

df = pd.read_csv("https://raw.githubusercontent.com/dm-fedorov/pandas_basic/master/data/wine.csv")
df.head()
# Out:
#   country                                        description designation  \
# 0      US  With a delicate, silky mouthfeel and bright ac...         NaN
# 1   Italy  D'Alceo is a drop dead gorgeous wine that ooze...     D'Alceo
# 2  France  The great dominance of Cabernet Sauvignon in t...         NaN
# 3   Italy  The modest cherry, dark berry and black tea no...         NaN
# 4      US  Exceedingly light in color, scent and flavor, ...         NaN
#
#    points    price    province          region_1         region_2  \
# 0      86   € 23,0  California     Central Coast    Central Coast
# 1      96  € 275,0     Tuscany           Toscana              NaN
# 2      91   € 40,0    Bordeaux        Haut-Médoc              NaN
# 3      81   € 15,0     Tuscany  Chianti Classico              NaN
# 4      83   € 25,0      Oregon      Rogue Valley  Southern Oregon
#
#                     variety                 winery
# 0                Pinot Noir        MacMurray Ranch
# ...

# %%
color = {
    "Chardonnay": "white",
    "Pinot Noir": "red",
    "Cabernet Sauvignon": "red",
    "Red Blend": "red",
    "Bordeaux-style Red Blend": "red",
    "Sauvignon Blanc": "white",
    "Syrah": "red",
    "Riesling": "white",
    "Merlot": "red",
    "Zinfandel": "red",
    "Sangiovese": "red",
    "Malbec": "red",
    "White Blend": "white",
    "Rosé": "other",
    "Tempranillo": "red",
    "Nebbiolo": "red",
    "Portuguese Red": "red",
    "Sparkling Blend": "other",
    "Shiraz": "red",
    "Corvina, Rondinella, Molinara": "red",
    "Rhône-style Red Blend": "red",
    "Barbera": "red",
    "Pinot Gris": "white",
    "Viognier": "white",
    "Bordeaux-style White Blend": "white",
    "Champagne Blend": "other",
    "Port": "red",
    "Grüner Veltliner": "white",
    "Gewürztraminer": "white",
    "Portuguese White": "white",
    "Petite Sirah": "red",
    "Carmenère": "red"
}

# %% [markdown]
# Вина какой области (province) получают наилучшие рейтинги?

# %% [markdown]
# На основе словаря color создайте переменную, в которой закодирован цвет вина.

# %%
df[df["variety"]=="Portuguese Red"]
# Out:
#         country                                        description  \
# 121    Portugal  The Quinta da Leda is high up the Douro, in th...
# 248    Portugal  This is a soft, fruity and easy wine. With sim...
# 250    Portugal  The estate wine of Malhadinha Nova is a seriou...
# 255    Portugal  An elegant style, the ripe fruit restrained an...
# 261    Portugal  A wine only made in the best years, this is ri...
# ...         ...                                                ...
# 19743  Portugal  Red fruits dominate a wine that is rich, full-...
# 19814  Portugal  All four of Dâo's indigenous red grapes—Tourig...
# 19841  Portugal  A bright and fruity wine that has plenty of ac...
# 19926  Portugal  Dense and powerful, this is an impressively co...
# 19948  Portugal  Perfumed wine, deliciously aromatic but also s...
#
#                   designation  points     price    province region_1 region_2  \
# 121            Quinta da Leda      90  € € 60,0       Douro      NaN      NaN
# ...

# %%
def color_update(row):
    if str(row['variety']) in color.keys():
      return color[row['variety']]
    else:
      return np.nan
    
df['color'] = df.apply(color_update, axis=1)

# %%
df
# Out:
#       country                                        description  \
# 0          US  With a delicate, silky mouthfeel and bright ac...
# 1       Italy  D'Alceo is a drop dead gorgeous wine that ooze...
# 2      France  The great dominance of Cabernet Sauvignon in t...
# 3       Italy  The modest cherry, dark berry and black tea no...
# 4          US  Exceedingly light in color, scent and flavor, ...
# ...       ...                                                ...
# 19995  France  Firm wine, with tannins to match the chunky st...
# 19996      US  The vineyard is on the Napa side of Carneros. ...
# 19997   Italy  Lighea is a terrific wine and an excellent pai...
# 19998   Italy  Organically farmed Cannonau grapes deliver sma...
# 19999      US  Grown on the Sonoma side of the appellation, i...
#
#            designation  points      price           province  \
# 0                  NaN      86   € € 23,0         California
# ...
